# %%
# !pip install simple_image_download
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# INFO: pip is looking at multiple versions of simple-image-download to determine which version is compatible with other requirements. This could take a while.
# ...

# %%
from simple_image_download import simple_image_download as simp 
response = simp.simple_image_download
lst=['Kaempferia galanga', 'Zingiber officinale', 'Alpinia galanga','Curcuma longa Linn']
for rep in lst:
 response().download(rep +' rhizome' , 300)
# Out:
# HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fbaec1d8df0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fbaec1d8d60>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fbaec1d8f40>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# ...

# %%
# !zip -r /content/simple_images.zip /content/simple_images
# Out:
#   adding: content/simple_images/ (stored 0%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/ (stored 0%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_8.jpg (deflated 42%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_95.jpg (stored 0%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_185.jpg (deflated 2%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_256.jpg (deflated 23%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_63.jpg (deflated 14%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_19.jpg (deflated 42%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_178.jpg (deflated 8%)
#   adding: content/simple_images/Curcuma longa Linn rhizome/Curcuma longa Linn rhizome_165.jpg (deflated 14%)
# ...
